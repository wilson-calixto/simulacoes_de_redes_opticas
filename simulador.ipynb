# %%
# %pylab inline
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

import pylab
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/wilson/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
MG = nx.MultiGraph()

for i in range(1,9):
    MG.add_node(i)

l = 20
    
for i in range(l):
    MG.add_edge(1, 2, key = 'lambda_'+str(i), weight=50)
    MG.add_edge(1, 4, key = 'lambda_'+str(i), weight=80)
    MG.add_edge(1, 6, key = 'lambda_'+str(i), weight=150)
    MG.add_edge(2, 3, key = 'lambda_'+str(i), weight=60)
    MG.add_edge(2, 4, key = 'lambda_'+str(i), weight=40)
    
    MG.add_edge(2, 5, key = 'lambda_'+str(i), weight=90)
    MG.add_edge(3, 5, key = 'lambda_'+str(i), weight=110)
    MG.add_edge(3, 8, key = 'lambda_'+str(i), weight=150)
    MG.add_edge(4, 6, key = 'lambda_'+str(i), weight=150)
    MG.add_edge(4, 7, key = 'lambda_'+str(i), weight=130)
    
    MG.add_edge(5, 7, key = 'lambda_'+str(i), weight=120)
    MG.add_edge(5, 8, key = 'lambda_'+str(i), weight=130)
    MG.add_edge(6, 7, key = 'lambda_'+str(i), weight=120)
    MG.add_edge(7, 8, key = 'lambda_'+str(i), weight=120)

# %%
nx.draw_networkx(MG, {1: (0, 10), 2: (5, 10), 3: (10, 10), 
                      4: (2.5, 5), 5: (7.5, 5), 6: (0, 0), 
                      7: (5, 0), 8: (10, 0)})

edge_labels=dict([((u,v,),d['weight'])
             for u,v,d in G.edges(data=True)])

nx.draw_networkx_edge_labels(MG, {1: (0, 10), 2: (5, 10), 3: (10, 10), 
                                  4: (2.5, 5), 5: (7.5, 5), 6: (0, 0), 
                                  7: (5, 0), 8: (10, 0)},
                             edge_labels=edge_labels)
limits=plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-af44be45f1ee> in <module>()
#       4
#       5 edge_labels=dict([((u,v,),d['weight'])
# ----> 6              for u,v,d in G.edges(data=True)])
#       7
#       8 nx.draw_networkx_edge_labels(MG, {1: (0, 10), 2: (5, 10), 3: (10, 10),
#
# NameError: name 'G' is not defined

# %%
MG_PacificBell = nx.MultiGraph()

MG_PacificBell.add_nodes_from(np.arange(0,17,1))

l = 20

for i in range(l):
    MG_PacificBell.add_edge(0, 2, key='lambda_'+str(i), weight=100)
    MG_PacificBell.add_edge(0, 5, key='lambda_'+str(i), weight=90)
    MG_PacificBell.add_edge(0, 6, key='lambda_'+str(i), weight=100)
    MG_PacificBell.add_edge(0, 10, key='lambda_'+str(i), weight=120)
    MG_PacificBell.add_edge(0, 12, key='lambda_'+str(i), weight=150)

    MG_PacificBell.add_edge(1, 5, key='lambda_'+str(i), weight=80)
    MG_PacificBell.add_edge(1, 6, key='lambda_'+str(i), weight=90)
    MG_PacificBell.add_edge(2, 3, key='lambda_'+str(i), weight=60)
    MG_PacificBell.add_edge(3, 12, key='lambda_'+str(i), weight=110)
    MG_PacificBell.add_edge(4, 5, key='lambda_'+str(i), weight=100)

    MG_PacificBell.add_edge(4, 12, key='lambda_'+str(i), weight=100)
    MG_PacificBell.add_edge(5, 7, key='lambda_'+str(i), weight=140)
    MG_PacificBell.add_edge(5, 15, key='lambda_'+str(i), weight=100)
    MG_PacificBell.add_edge(5, 14, key='lambda_'+str(i), weight=100)
    MG_PacificBell.add_edge(6, 7, key='lambda_'+str(i), weight=120)

    MG_PacificBell.add_edge(6, 8, key='lambda_'+str(i), weight=90)
    MG_PacificBell.add_edge(6, 15, key='lambda_'+str(i), weight=100)
    MG_PacificBell.add_edge(8, 16, key='lambda_'+str(i), weight=90)
    MG_PacificBell.add_edge(9, 10, key='lambda_'+str(i), weight=150)
    MG_PacificBell.add_edge(9, 16, key='lambda_'+str(i), weight=90)

    MG_PacificBell.add_edge(11, 12, key='lambda_'+str(i), weight=100)
    MG_PacificBell.add_edge(11, 13, key='lambda_'+str(i), weight=100)
    MG_PacificBell.add_edge(13, 14, key='lambda_'+str(i), weight=90)

# %%
nodes_pacific_bell_series = pd.DataFrame({'nodes': np.arange(0,17,1), 
                                         'pos_x': [16, 16, 17, 12, 30, 28, 6, 14, 0, 0, 8, 38, 22, 42, 40, 17, 0],
                                         'pos_y': [16, 22, 6, 0, 14, 28, 28, 32, 28, 16, 8, 0, 0, 10, 24, 26, 22]})
nodes_pacific_bell_series.to_csv('nodes_PacificBellModificada.csv')

# %%
edges_pacific_bell_df = pd.DataFrame({'n1': [0, 0, 0, 0, 0, 1, 1, 2, 3, 4, 4, 5, 5, 5, 6, 6, 6, 8, 9, 9, 11, 11, 13],
                                      'n2': [2, 5, 6, 10, 12, 5, 6, 3, 12, 5, 12, 7, 15, 14, 7, 8, 15, 16, 10, 16, 12, 13, 14],
                                      'weights': [100, 90, 100, 120, 150, 80, 90, 60, 110, 100, 100, 140, 100, 100, 120, 90, 
                                                  100, 90, 150, 90, 100, 100, 90]})
edges_pacific_bell_df.to_csv('edges_PacificBellModificada.csv')

# %%
pylab.rcParams['figure.figsize'] = (12.0, 8.0)
nx.draw_networkx(MG_PacificBell, {0: (16, 16), 1: (16, 22), 2: (17, 6), 3: (12, 0), 4: (30, 14), 5: (28, 28),
                                  6: (6, 28), 7: (14, 32), 8: (0, 28), 9: (0, 16), 10: (8, 8), 11: (38, 0),
                                  12: (22, 0), 13: (42, 10), 14: (40, 24), 15: (17, 26), 16: (0, 22)})

edge_labels=dict([((u,v,),d['weight'])
             for u,v,d in MG_PacificBell.edges(data=True)])

nx.draw_networkx_edge_labels(MG_PacificBell, {0: (16, 16), 1: (16, 22), 2: (17, 6), 3: (12, 0), 4: (30, 14), 5: (28, 28),
                                              6: (6, 28), 7: (14, 32), 8: (0, 28), 9: (0, 16), 10: (8, 8), 11: (38, 0),
                                              12: (22, 0), 13: (42, 10), 14: (40, 24), 15: (17, 26), 16: (0, 22)},
                             edge_labels=edge_labels)

limits=plt.axis('off')
plt.savefig('PacificBellModificada.png')

# %%
origem=12
destino=11
acabou=False
arq = open('lista.txt', 'w')
texto = []




while not acabou:
    if(acabou):
        break
    for i in range(l):
        chave='lambda_'+str(i)
        # calcula o menor caminho 
        #TODO salvar isso em csv enquanto for gerando o menor caminho


        try:
            lista_de_nos=nx.dijkstra_path(MG_PacificBell, origem, destino)
            peso=nx.dijkstra_path_length(MG_PacificBell, origem, destino)
            print(lista_de_nos)
            texto.append("caminho - "+str(lista_de_nos)+' peso - '+str(peso)+"\n")

            #remove os lambdas usados do grafo
            for i in range(len(lista_de_nos)):    
                if(i+1 < len(lista_de_nos)):       
                    #print(nx.dijkstra_path(MG,lista_de_nos[i],lista_de_nos[i+1]))
                    MG_PacificBell.remove_edge(lista_de_nos[i],lista_de_nos[i+1], key=chave)

        except :
            print ("sem caminhos")
            acabou=True
            break
arq.writelines(texto)            
arq.close()
# Out:
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# [12, 4, 5, 14, 13, 11]
# sem caminhos

# %%
arq = open('lista.txt', 'w')
texto = """
Lista de Alunos
---
João da Silva
José Lima
Maria das Dores
"""
arq.write(texto)
arq.close()
